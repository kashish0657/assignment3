# %% [markdown]
# # 2nd FEB ASSIGNMENT

# %%
1.ans:- When to use 

        For Loop- Actually, for loops are used when we have a block of code which we want to repeat a fixed
                number of times and for loop is always used in combination with an iterable object, like or a range. 
                The python for statement iterates over the member of a sequence in order, executing the block each time.
    Example:- 
                n=int(input("enter a number"))
                i=range(1,11)
                result=0
                for i in i:
                    result*n*i
                    printf(n,"x",i,"=",result)
                    
        While Loop- Actually, the while loop is used when it is impossible to determine the exat number of loop
                    iteration in advance. 
    Example:-
                count=0
                n=int(input("enter a number"))
                while n =10:
                    count=count+1
                    n=n/3
                print(count,"times can be divided by 3before it is less than or equal to 10.")

# %%
2.ans:-  # using for loop

sum=0
product=1

i=range(1,11)

for k in i:
    sum=sum+k
    product=produt*k

print("sum of the first 10 natural number is", sum,"\n product of first 10 natural number is",product)

# using while loop

sum=0
product=1
i=1

while i=10:
    sum=sum+i
    product=product*i
    i-i+1
    
print("sum of the first 10 natural numbers is", sum, "\n product of the first 10 natural number is",product)

# %%
3.ans:- 

bill=0
temp=0
temp1=0
temp2=0
units=int(input("enter your units:-"))

if units>0 and units<=100:
    bill=units*4.5
    print("Total Electricity Bill=",bill)
    
elif units>100 and units<=200:
    temp=4.5*100
    units=units%100
    bill=units*6+temp
    print("Total Electricity Bill=",bill)
    
elif units>200 and units<=300:
    temp=4.5*100
    temp1=6*100
    units=units%200
    bill=units*10+temp+temp1
    print("Total Electricity Bill=",bill)
    
elif units>300:
    temp=4.5*100
    temp1=6*100
    temp2=10*100
    units=units%300
    bill=units*20+temp+temp1+temp2
    print("Total Electricity Bill=",bill)

# %%
4.ans:-

# using while loop and for loop

i=1

l_cube=[]
l_divisible_by_4_or_5=[]

while i<=100:
    l_cube.append(i**3)
    i=i+1
else:
    for j in l_cube:
        if j%4==0 or j%5==0:
            l_divisible_by_4_or_5.append(j)
print("cube of each number\n\n",l_cube)
print("\n\n Divisible by 4 or 5\n\n",l_divisible_by_4_or_5)

#using only for loop

l=list(range(1,101))

l_cube=[]
l_divisible_by_4_or_5=[]

for i in l:
    l_cube.append(i**3)
else:
    for j in l_cube:
        if j%4==0 or j%5==0:
            l_divisible_by_4_or_5.append(j)
print("cube of each number\n\n",l_cube)
print("\n\n Divisible by 4 or 5\n\n",l_divisible_by_4_or_5)

# %%
5.ans:-

string="I want to become data scientist"
vowels=['a','e','i','o','u','A','E','I','O','U']
total_vowels=0
count=0
for i in vowels:
    count=string.count(i)
    total_vowels=total_vowels+count
